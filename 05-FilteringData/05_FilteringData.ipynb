# %% [markdown]
# # $Pandas$ $ile$ $Veri$ $Filtreleme$
# ***
# ### $Bool$ $Serilerin$ $Filtreleme$ $İşleminde$ $Kullanımı$

# %%
# Pandas kütüphanesini import edelim.
import pandas as pd

# %%
# Kullanacağımız veri setlerini import edelim.
houses = pd.read_csv("../Sources/data/kc_house_data.csv")
titanic = pd.read_csv("../Sources/data/titanic.csv")
netflix = pd.read_csv("../Sources/data/netflix_titles.csv", sep="|", index_col=0)

# %%
# Titanic veri setinin ilk beş örneğini dataFrame değişkenine atalım.
dataFrame = titanic.head()

# %%
dataFrame
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# İlk beş örneğin cinsiyet serisini inceleyelim.
dataFrame["sex"]
# Out:
# 0    female
# 1      male
# 2    female
# 3      male
# 4    female
# Name: sex, dtype: object

# %%
# Peki bu örneklerden/yolculardan hangileri kadın?
# Bunu öğrenebilmek için mantıksal operatör kullanıp seri içerisideki kadınların True olacak şekilde gösterilmesini sağlayalım.
# Bu şekilde bir bool seri yaratmış oluyoruz.
dataFrame["sex"] == 'female'
# Out:
# 0     True
# 1    False
# 2     True
# 3    False
# 4     True
# Name: sex, dtype: bool

# %%
# Şimdi de dataFrame içerisindeki kadın yolcuları görelim.
# dataFrame["sex"] == 'female' yapısı ile kadın yolcuların, True olacak şekilde seri içerisinde gösterimini sağlamıştık.
# Bool seri kullanarak dataFrame içerisindeki kadın yolcuları filtreleyebiliriz.
dataFrame[dataFrame["sex"] == 'female']
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
dataFrame
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %%
# Şimdi de ilk beş örnek içerisinde Titanic kazasından kurtulamayan yolcuları bulalım.
dataFrame[dataFrame["survived"] == 0]
# Out:
#    pclass  survived                                             name     sex  \
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket    fare    cabin embarked boat body  \
# 2   2      1      2  113781  151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781  151.55  C22 C26        S    ?  135
# 4  25      1      2  113781  151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Kendimiz de bir bool tipinde seri oluşturup bunu herhangi bir dataFrame'i filtrelemek için kullanabiliriz.
bools = [True, False, True, True, True]
dataFrame[bools]
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#   age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0  29      0      0   24160  211.3375       B5        S    2    ?
# 2   2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3  30      1      2  113781    151.55  C22 C26        S    ?  135
# 4  25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
# Titanic kazasından kurtulan tüm yolcuları filtreleyelim.
titanic[titanic["survived"] == 1]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %%
# Titanic yolcularından 18 yaşında olanları görelim.
titanic[titanic["age"] == "18"]
# Out:
#       pclass  survived                                               name  \
# 11         1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 198        1         1  Marvin, Mrs. Daniel Warner (Mary Graham Carmic...
# 228        1         0         Penasco y Castellana, Mr. Victor de Satode
# 250        1         1                         Ryerson, Miss. Emily Borie
# 270        1         1     Smith, Mrs. Lucien Philip (Mary Eloise Hughes)
# 289        1         1                                Taussig, Miss. Ruth
# 326        2         0                         Andrew, Mr. Edgardo Samuel
# 331        2         0                           Bailey, Mr. Percy Andrew
# 386        2         0                          Davies, Mr. Charles Henry
# 394        2         0                                Dibden, Mr. William
# 395        2         1                                Doling, Miss. Elsie
# 405        2         0                          Fahlstrom, Mr. Arne Jonas
# ...

# %%
# Titanic yolcularından 18 yaşında olanların isimlerini, yaşlarını ve kurtulup kurtulamadıklarını görelim.
titanic[titanic["age"] == "18"][["name", "age", "survived"]]
# Out:
#                                                    name age  survived
# 11    Astor, Mrs. John Jacob (Madeleine Talmadge Force)  18         1
# 198   Marvin, Mrs. Daniel Warner (Mary Graham Carmic...  18         1
# 228          Penasco y Castellana, Mr. Victor de Satode  18         0
# 250                          Ryerson, Miss. Emily Borie  18         1
# 270      Smith, Mrs. Lucien Philip (Mary Eloise Hughes)  18         1
# 289                                 Taussig, Miss. Ruth  18         1
# 326                          Andrew, Mr. Edgardo Samuel  18         0
# 331                            Bailey, Mr. Percy Andrew  18         0
# 386                           Davies, Mr. Charles Henry  18         0
# 394                                 Dibden, Mr. William  18         0
# 395                                 Doling, Miss. Elsie  18         1
# 405                           Fahlstrom, Mr. Arne Jonas  18         0
# ...

# %%
# Titanic yolcularından 18 yaşında olanların ve kazadan kurtulanların isimlerini ve yaşlarını görelim.
titanic[(titanic["age"] == "18") & (titanic["survived"] == 0)][["name"]]
# Out:
#                                                name
# 228      Penasco y Castellana, Mr. Victor de Satode
# 326                      Andrew, Mr. Edgardo Samuel
# 331                        Bailey, Mr. Percy Andrew
# 386                       Davies, Mr. Charles Henry
# 394                             Dibden, Mr. William
# 405                       Fahlstrom, Mr. Arne Jonas
# 408                   Fillbrook, Mr. Joseph Charles
# 445                           Hiltunen, Miss. Marta
# 619                          Allum, Mr. Owen George
# 636   Arnold-Franchi, Mrs. Josef (Josefine Franchi)
# 665                           Barbara, Miss. Saiide
# 676                    Bjorklund, Mr. Ernst Herbert
# 695                         Burns, Miss. Mary Delia
# 698                            Cacic, Mr. Jego Grga
# 717                     Chronopoulos, Mr. Demetrios
# 786                  Edvardsson, Mr. Gustaf Hjalmar
# 799                 Fischer, Mr. Eberhard Thelander
# ...

# %%
titanic[titanic["pclass"] != 1]
# Out:
#       pclass  survived                                   name     sex   age  \
# 323        2         0                    Abelson, Mr. Samuel    male    30
# 324        2         1  Abelson, Mrs. Samuel (Hannah Wizosky)  female    28
# 325        2         0         Aldworth, Mr. Charles Augustus    male    30
# 326        2         0             Andrew, Mr. Edgardo Samuel    male    18
# 327        2         0               Andrew, Mr. Frank Thomas    male    25
# ...      ...       ...                                    ...     ...   ...
# 1304       3         0                   Zabour, Miss. Hileni  female  14.5
# 1305       3         0                  Zabour, Miss. Thamine  female     ?
# 1306       3         0              Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                    Zakarian, Mr. Ortin    male    27
# 1308       3         0                     Zimmerman, Mr. Leo    male    29
#
# ...

# %% [markdown]
# ***
# ## $Karşılaştırma$ $Operatörlerinin$ $Filtreleme$ $İşlemlerinde$ $Kullanımı$
# ***

# %%
# Fiyatı 5.000.000'dan büyük olan evleri listeleyelim.
houses[houses["price"] > 5_000_000]
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 1164  1247600105  20141020T000000  5110800.0         5       5.25
# 1315  7558700030  20150413T000000  5300000.0         6       6.00
# 1448  8907500070  20150413T000000  5350000.0         5       5.00
# 3914  9808700762  20140611T000000  7062500.0         5       4.50
# 4411  2470100110  20140804T000000  5570000.0         5       5.75
# 7252  6762700020  20141013T000000  7700000.0         6       8.00
# 9254  9208900037  20140919T000000  6885000.0         6       7.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 1164         8010     45517     2.0           1     4  ...     12        5990
# 1315         7390     24829     2.0           1     4  ...     12        5000
# 1448         8000     23985     2.0           0     4  ...     12        6720
# 3914        10040     37325     2.0           1     2  ...     11        7680
# ...

# %%
# 10'dan fazla yatak odası olan evleri listeleyelim.
houses[houses['bedrooms'] > 10]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000  520000.0        11       3.00
# 15870  2402100895  20140625T000000  640000.0        33       1.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# 15870        1040            580      1947             0    98103  47.6878
#
#           long  sqft_living15  sqft_lot15
# 8757  -122.363           1420        4960
# 15870 -122.331           1330        4700
#
# [2 rows x 21 columns]

# %%
# 10 ve 10'dan fazla yatak odası olan evleri listeleyelim.
houses[houses['bedrooms'] >= 10]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 8757   1773100755  20140821T000000   520000.0        11       3.00
# 13314   627300145  20140814T000000  1148000.0        10       5.25
# 15161  5566100170  20141029T000000   650000.0        10       2.00
# 15870  2402100895  20140625T000000   640000.0        33       1.75
# 19254  8812401450  20141229T000000   660000.0        10       3.00
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 8757          3000      4960     2.0           0     0  ...      7
# 13314         4590     10920     1.0           0     2  ...      9
# 15161         3610     11914     2.0           0     0  ...      7
# 15870         1620      6000     1.0           0     0  ...      7
# 19254         2920      3745     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 8757         2400            600      1918          1999    98106  47.5560
# ...

# %%
houses[houses["sqft_living"] < 500]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 465    8658300340  20140523T000000   80000.0         1       0.75
# 860    1723049033  20140620T000000  245000.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 4203   1437500015  20140709T000000  150000.0         3       0.75
# 4868   6896300380  20141002T000000  228000.0         0       1.00
# 8133   7849202585  20140904T000000  170000.0         1       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 11500  4322200105  20150331T000000  229050.0         1       1.00
# 12075  8655900162  20150219T000000  156000.0         1       0.75
# 14466  7549801385  20140612T000000  280000.0         1       0.75
# 15248  1320069249  20141020T000000  192500.0         1       1.00
# 15381  2856101479  20140701T000000  276000.0         1       0.75
# 17394   745000005  20140825T000000  145000.0         1       0.75
# ...

# %%
houses[houses["sqft_living"] <= 500]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 465    8658300340  20140523T000000   80000.0         1       0.75
# 860    1723049033  20140620T000000  245000.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 4203   1437500015  20140709T000000  150000.0         3       0.75
# 4651    859000110  20141002T000000  125000.0         1       1.00
# 4868   6896300380  20141002T000000  228000.0         0       1.00
# 8133   7849202585  20140904T000000  170000.0         1       1.00
# 8623   6303400395  20150130T000000  325000.0         1       0.75
# 11500  4322200105  20150331T000000  229050.0         1       1.00
# 12075  8655900162  20150219T000000  156000.0         1       0.75
# 14466  7549801385  20140612T000000  280000.0         1       0.75
# 15248  1320069249  20141020T000000  192500.0         1       1.00
# 15381  2856101479  20140701T000000  276000.0         1       0.75
# ...

# %% [markdown]
# **Yaptığımız tüm örneklerde aslında bir bool seri oluşturup bu bool seriyi DataFrame'e bir parametre olarak verip bool seri'nin True değerine sahip indexlerinden DataFrame'deki indexlere denk gelen örnekleri/satırları görüntülüyoruz.**

# %% [markdown]
# ***
# ## $between()$ $Metodunun$ $Filtreleme$ $İşlemlerinde$ $Kullanımı$
# ***

# %% [markdown]
# **`Series.between(left, right, inclusive='both')`, metodun prototipi soldaki gibidir. *between()* metodu, hedeflenen seri için, belirtilen aralıklarda değer bulundurup bulundurmadığına göre True ya da False değerlerinden oluşan bir bool vektör döner. `inclusive` parametresi, "left", "right", "both" ve "neither" değişkenlerini alabilir. Default olarak "both" değişkeni atanmıştır. "inclusive" parametresine "left" verilirse [left, right), "right" verilirse (left, right], "both" verilirse [left, right], "neither" verilirse (left, right) mantığı ile filtreleme yapılır.**

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
# 4 dahil edilmez
houses["bedrooms"].head().between(2, 4, inclusive="left")
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# Name: bedrooms, dtype: bool

# %%
# 2 dahil edilmez
houses["bedrooms"].head().between(2, 4, inclusive="right")
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# 4     True
# Name: bedrooms, dtype: bool

# %%
# 2 ve 4 dahil edilmez
houses["bedrooms"].head().between(2, 4, inclusive="neither")
# Out:
# 0     True
# 1     True
# 2    False
# 3    False
# 4     True
# Name: bedrooms, dtype: bool

# %%
# 2 ve 4 dahil edilir
houses["bedrooms"].head().between(2, 4, inclusive="both")
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# 4    True
# Name: bedrooms, dtype: bool

# %%
# 5 ve 7 adet aralığında yatak odasına sahip olan evlerin bool vektörünü görelim.
houses["bedrooms"].between(5, 7)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21608    False
# 21609    False
# 21610    False
# 21611    False
# 21612    False
# Name: bedrooms, Length: 21613, dtype: bool

# %%
# 5-7 adet aralığında yatak odasına sahip olan ve olmayan ev sayılarını ayrı ayrı görelim.
houses["bedrooms"].between(5, 7).value_counts()
# Out:
# False    19702
# True      1911
# Name: bedrooms, dtype: int64

# %%
# 5 ve 7 adet aralığında yatak odasına sahip olan evleri görelim.
houses[houses["bedrooms"].between(5, 7)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 14     1175000570  20150312T000000   530000.0         5       2.00
# 22     7137970340  20140703T000000   285000.0         5       2.50
# 42     7203220400  20140707T000000   861990.0         5       2.75
# 51     7231300125  20150217T000000   345000.0         5       2.50
# 54     4217401195  20150303T000000   920000.0         5       2.25
# ...           ...              ...        ...       ...        ...
# 21564  7168100015  20141009T000000   579950.0         5       2.75
# 21576  9253900271  20150107T000000  3567000.0         5       4.50
# 21593  8672200110  20150317T000000  1088000.0         5       3.75
# 21596  7502800100  20140813T000000   679950.0         5       2.75
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 14            1810      4850     1.5           0     0  ...      7
# ...

# %%
# 5 ve 7 adet aralığında yatak odasına sahip olan evlerin fiyatlarını görelim.
houses[houses["bedrooms"].between(5, 7)]["price"]
# Out:
# 14        530000.0
# 22        285000.0
# 42        861990.0
# 51        345000.0
# 54        920000.0
#            ...
# 21564     579950.0
# 21576    3567000.0
# 21593    1088000.0
# 21596     679950.0
# 21600    1537000.0
# Name: price, Length: 1911, dtype: float64

# %%
# 5 ve 7 adet aralığında yatak odasına sahip olan evlerin fiyatlarını azalan sırada görelim.
houses[houses["bedrooms"].between(5, 7)]["price"].sort_values(ascending=False)
# Out:
# 7252     7700000.0
# 3914     7062500.0
# 9254     6885000.0
# 4411     5570000.0
# 1448     5350000.0
#            ...
# 3540      175000.0
# 12338     175000.0
# 2810      175000.0
# 5577      158550.0
# 15810     133000.0
# Name: price, Length: 1911, dtype: float64

# %%
houses[houses["grade"].between(11,13)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 70     1525059190  20140912T000000  1040000.0         5       3.25
# 153    7855801670  20150401T000000  2250000.0         4       3.25
# 269    7960900060  20150504T000000  2900000.0         4       3.25
# 270    4054500390  20141007T000000  1365000.0         4       4.75
# ...           ...              ...        ...       ...        ...
# 21532   324069112  20140617T000000  1325000.0         4       4.00
# 21548  8835770330  20140819T000000  1057000.0         2       1.50
# 21551  1561750040  20141224T000000  1375000.0         5       4.50
# 21590  7430200100  20140514T000000  1222500.0         4       3.50
# 21600   249000205  20141015T000000  1537000.0         5       3.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 5             5420    101930     1.0           0     0  ...     11
# ...

# %% [markdown]
# ***
# ## $isin()$ $Metodunun$ $Filtreleme$ $İşlemlerinde$ $Kullanımı$
# ***

# %% [markdown]
# **Metodun prototipi: `Series.isin(values)`**
#
# **Kendisine verilen liste içerisinde bulunan değerlerin, üzerinde çalıştığı seri içerisinde olup olmadığına bakar ve buna göre geriye bool vektörü döner. Metoda parametre olarak string tipinde bir değişken verilirse hata fırlatır.**

# %%
# Bir ülke listesi oluşturalım.
countries = ["India", "Japan", "South Korea"]

# %%
# Oluşturduğumuz ülke listesi içerisindeki değerleri "country" sütununu baz alarak DataFrame satırları ile karşılaştıralım.
# Buna göre geri dönen bool vektörünü görüntüleyelim.
netflix["country"].isin(countries)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 8802    False
# 8803    False
# 8804    False
# 8805    False
# 8806     True
# Name: country, Length: 8807, dtype: bool

# %%
# Bool vektörünü "netflix" DataFrame'ine atayalım.
# Buna göre True değerine sahip satırları görüntüleyelim.
netflix[netflix["country"].isin(countries)]
# Out:
#      show_id     type                                              title  \
# 4         s5  TV Show                                       Kota Factory
# 24       s25    Movie                                              Jeans
# 39       s40  TV Show                                       Chhota Bheem
# 50       s51  TV Show                                      Dharmakshetra
# 51       s52    Movie  InuYasha the Movie 2: The Castle Beyond the Lo...
# ...      ...      ...                                                ...
# 8773   s8774    Movie                                Yanda Kartavya Aahe
# 8775   s8776  TV Show                                    Yeh Meri Family
# 8798   s8799    Movie                                           Zed Plus
# 8799   s8800    Movie                                              Zenda
# 8806   s8807    Movie                                             Zubaan
#
#                      director  \
# 4                         NaN
# ...

# %%
# Belirttiğimiz ülkeler için True değerine sahip satırları, video içerik başlığı, video içerik tipi ve çekimin yapıldığı ülke bazında inceleyelim.
netflix[netflix["country"].isin(countries)][["title", "type", "country"]]
# Out:
#                                                   title     type country
# 4                                          Kota Factory  TV Show   India
# 24                                                Jeans    Movie   India
# 39                                         Chhota Bheem  TV Show   India
# 50                                        Dharmakshetra  TV Show   India
# 51    InuYasha the Movie 2: The Castle Beyond the Lo...    Movie   Japan
# ...                                                 ...      ...     ...
# 8773                                Yanda Kartavya Aahe    Movie   India
# 8775                                    Yeh Meri Family  TV Show   India
# 8798                                           Zed Plus    Movie   India
# 8799                                              Zenda    Movie   India
# 8806                                             Zubaan    Movie   India
#
# [1416 rows x 3 columns]

# %%
mature = netflix["rating"].isin(["TV-MA", "R", "PG-13"])

# %%
netflix[mature]
# Out:
#      show_id     type                  title                 director  \
# 0         s1    Movie   Dick Johnson Is Dead          Kirsten Johnson
# 1         s2  TV Show          Blood & Water                      NaN
# 2         s3  TV Show              Ganglands          Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans                      NaN
# 4         s5  TV Show           Kota Factory                      NaN
# ...      ...      ...                    ...                      ...
# 8791   s8792    Movie            Young Adult            Jason Reitman
# 8798   s8799    Movie               Zed Plus  Chandra Prakash Dwivedi
# 8801   s8802    Movie                Zinzana          Majid Al Ansari
# 8802   s8803    Movie                 Zodiac            David Fincher
# 8804   s8805    Movie             Zombieland          Ruben Fleischer
#
#                                                    cast  \
# 0                                                   NaN
# ...

# %% [markdown]
# ***
# ## $\&$ $(VE)$ $Mantıksal$ $Operatörü$ $ile$ $Filtreleme$ $İşlemi$
# ***

# %%
women = titanic["sex"] == 'female'
died = titanic["survived"] == 0

# %%
# Titanic kazasında ölen kadınları listeleyelim.
titanic[women & died]
# Out:
#       pclass  survived                                               name  \
# 2          1         0                       Allison, Miss. Helen Loraine
# 4          1         0    Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 105        1         0                           Evans, Miss. Edith Corse
# 169        1         0                         Isham, Miss. Ann Elizabeth
# 286        1         0             Straus, Mrs. Isidor (Rosalie Ida Blun)
# ...      ...       ...                                                ...
# 1273       3         0                 Vander Planke, Miss. Augusta Maria
# 1276       3         0  Vander Planke, Mrs. Julius (Emelia Maria Vande...
# 1279       3         0               Vestrom, Miss. Hulda Amanda Adolfina
# 1304       3         0                               Zabour, Miss. Hileni
# 1305       3         0                              Zabour, Miss. Thamine
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...

# %%
# Lebiderya olup fiyatı 500.000'den az olan evleri listeleyelim.
houses[(houses["waterfront"] == 1) & (houses["price"] < 500_000)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 264    2123039032  20141027T000000  369900.0         1       0.75
# 1168   3523029041  20141009T000000  290000.0         2       0.75
# 1949   1922039062  20150420T000000  480000.0         2       1.50
# 3829   8550001515  20141001T000000  429592.0         2       2.75
# 6102    222029026  20140917T000000  340000.0         2       0.75
# 8277    221029019  20150428T000000  400000.0         3       2.50
# 8450    121039042  20150313T000000  425000.0         3       2.75
# 11556  2013802030  20140911T000000  357000.0         3       2.00
# 14827  2423029009  20140617T000000  465000.0         2       2.00
# 16570  2923039243  20141113T000000  340000.0         4       1.00
# 18275  2781600195  20141117T000000  285000.0         1       1.00
# 18848  7631800110  20140918T000000  380000.0         3       2.50
# 19002  5216200090  20140616T000000  385000.0         2       1.00
#
# ...

# %%
houseView = houses["view"] == 4
houseGrade = houses["grade"] >= 11

# %%
houses[(houseGrade) & (houseView)]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 540     622049114  20150218T000000  2125000.0         3       2.50
# 1164   1247600105  20141020T000000  5110800.0         5       5.25
# 1315   7558700030  20150413T000000  5300000.0         6       6.00
# 1448   8907500070  20150413T000000  5350000.0         5       5.00
# 2085   8106100105  20141114T000000  3850000.0         4       4.25
# 2444   7524900003  20141210T000000  3278000.0         2       1.75
# 2626   7738500731  20140815T000000  4500000.0         5       5.50
# 2713   7851980260  20140730T000000  1110000.0         5       3.50
# 3157   1827200265  20140911T000000  1899000.0         2       2.75
# 3586   9272200090  20150204T000000  1598890.0         4       4.50
# 4013    724069059  20140509T000000  2400000.0         3       2.25
# 4190   2303900090  20140729T000000  2880500.0         4       2.50
# 4406   3505100756  20141106T000000  2050000.0         4       3.00
# ...

# %%
high_quality = houses["grade"] >= 11
good_view = houses["view"] == 4
smaller = houses["sqft_living"] <= 3000

# %%
houses[high_quality & good_view & smaller]
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 4013  724069059  20140509T000000  2400000.0         3       2.25         3000
#
#       sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 4013     11665     1.5           1     4  ...     11        3000
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 4013              0      2001             0    98075  47.5884 -122.086
#
#       sqft_living15  sqft_lot15
# 4013           3000       15959
#
# [1 rows x 21 columns]

# %% [markdown]
# ***
# ## $|$ $(YA$ $DA)$ $Mantıksal$ $Operatörü$ $ile$ $Filtreleme$ $İşlemi$
# ***

# %%
houses[houses["yr_built"] >= 2014]
houses[houses["yr_renovated"] >= 2014]
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 379    7132300695  20150421T000000   435000.0         3       1.50
# 435    2268400350  20140916T000000   749000.0         4       2.50
# 891    1962200435  20141110T000000  1010000.0         4       1.00
# 1379   1453600202  20140520T000000   520000.0         4       3.50
# 1449   8651430560  20140522T000000   180000.0         3       1.00
# ...           ...              ...        ...       ...        ...
# 19174  2420069220  20141203T000000   209000.0         3       1.00
# 19276  2397100705  20140714T000000  1518630.0         4       4.25
# 19444   582000644  20150501T000000   872500.0         4       2.00
# 19593   421059018  20141104T000000   257000.0         3       1.75
# 20447  3319500628  20150212T000000   356999.0         3       1.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 379           1300      3348     1.5           0     0  ...      7
# ...

# %%
houses[(houses["yr_built"] >= 2014) | (houses["yr_renovated"] >= 2014)]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
netflix[netflix["director"] == "David Fincher"]
# Out:
#      show_id   type                            title       director  \
# 600     s601  Movie                         The Game  David Fincher
# 1595   s1596  Movie                             MANK  David Fincher
# 7701   s7702  Movie                       Panic Room  David Fincher
# 8320   s8321  Movie  The Girl with the Dragon Tattoo  David Fincher
# 8511   s8512  Movie               The Social Network  David Fincher
# 8802   s8803  Movie                           Zodiac  David Fincher
#
#                                                    cast  \
# 600   Michael Douglas, Sean Penn, Deborah Kara Unger...
# 1595  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 7701  Jodie Foster, Forest Whitaker, Dwight Yoakam, ...
# 8320  Daniel Craig, Rooney Mara, Christopher Plummer...
# 8511  Jesse Eisenberg, Andrew Garfield, Justin Timbe...
# 8802  Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
#
#                             country         date_added  release_year rating  \
# ...

# %%
netflix[netflix["director"] == "Martin Scorsese"]
# Out:
#      show_id   type                                              title  \
# 1358   s1359  Movie                                     Shutter Island
# 2632   s2633  Movie                       No Direction Home: Bob Dylan
# 2860   s2861  Movie                                               Hugo
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111   s6112  Movie                    Alice Doesn't Live Here Anymore
# 6826   s6827  Movie                                  Gangs of New York
# 6880   s6881  Movie                                         GoodFellas
# 7431   s7432  Movie                                       Mean Streets
# 7820   s7821  Movie                                        Raging Bull
# 8272   s8273  Movie                                       The Departed
# 8735   s8736  Movie                    Who's That Knocking at My Door?
#
# ...

# %%
netflix[(netflix["director"] == "David Fincher") | (netflix["director"] == "Martin Scorsese")]
# Out:
#      show_id   type                                              title  \
# 600     s601  Movie                                           The Game
# 1358   s1359  Movie                                     Shutter Island
# 1595   s1596  Movie                                               MANK
# 2632   s2633  Movie                       No Direction Home: Bob Dylan
# 2860   s2861  Movie                                               Hugo
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111   s6112  Movie                    Alice Doesn't Live Here Anymore
# 6826   s6827  Movie                                  Gangs of New York
# 6880   s6881  Movie                                         GoodFellas
# 7431   s7432  Movie                                       Mean Streets
# 7701   s7702  Movie                                         Panic Room
# ...

# %%
netflix[netflix["director"].isin(["David Fincher", "Martin Scorsese"])]
# Out:
#      show_id   type                                              title  \
# 600     s601  Movie                                           The Game
# 1358   s1359  Movie                                     Shutter Island
# 1595   s1596  Movie                                               MANK
# 2632   s2633  Movie                       No Direction Home: Bob Dylan
# 2860   s2861  Movie                                               Hugo
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
# 6111   s6112  Movie                    Alice Doesn't Live Here Anymore
# 6826   s6827  Movie                                  Gangs of New York
# 6880   s6881  Movie                                         GoodFellas
# 7431   s7432  Movie                                       Mean Streets
# 7701   s7702  Movie                                         Panic Room
# ...

# %%
fincher = netflix["director"] == "David Fincher"
scorsese = netflix["director"] == "Martin Scorsese"
recent = netflix["release_year"] > 2015

# %%
netflix[(fincher | scorsese) & recent]
# Out:
#      show_id   type                                              title  \
# 1595   s1596  Movie                                               MANK
# 3227   s3228  Movie                                       The Irishman
# 3759   s3760  Movie  Rolling Thunder Revue: A Bob Dylan Story by Ma...
#
#              director                                               cast  \
# 1595    David Fincher  Gary Oldman, Amanda Seyfried, Charles Dance, L...
# 3227  Martin Scorsese  Robert De Niro, Al Pacino, Joe Pesci, Harvey K...
# 3759  Martin Scorsese  Bob Dylan, Allen Ginsberg, Joan Baez, Patti Sm...
#
#             country         date_added  release_year rating duration  \
# 1595  United States   December 4, 2020          2020      R  133 min
# 3227  United States  November 27, 2019          2019      R  209 min
# 3759  United States      June 12, 2019          2019  TV-MA  142 min
#
#                             listed_in  \
# 1595       Dramas, Independent Movies
# ...

# %% [markdown]
# ***
# ## $Bitwise$ $Negation$ $(Bitsel$ $Tersini$ $Alma)$ $Operatörü$ $ile$ $Filtreleme$ $İşlemi$
# ***

# %%
df = titanic.head()

# %%
women = df["sex"] == 'female'

# %%
df[~women]
# Out:
#    pclass  survived                                  name   sex     age  \
# 1       1         1        Allison, Master. Hudson Trevor  male  0.9167
# 3       1         0  Allison, Mr. Hudson Joshua Creighton  male      30
#
#    sibsp  parch  ticket    fare    cabin embarked boat body  \
# 1      1      2  113781  151.55  C22 C26        S   11    ?
# 3      1      2  113781  151.55  C22 C26        S    ?  135
#
#                          home.dest
# 1  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON

# %%
newly_built = houses["yr_built"] >= 2014
newly_renovated = houses["yr_renovated"] >= 2014
recent_homes = newly_built | newly_renovated

# %%
houses[recent_homes]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 42     7203220400  20140707T000000  861990.0         5       2.75
# 63     9528102996  20141207T000000  549000.0         3       1.75
# 133    8929000270  20140512T000000  453246.0         3       2.50
# 139    2767603505  20140507T000000  519950.0         3       2.25
# 211    1025049114  20140717T000000  625504.0         3       2.25
# ...           ...              ...       ...       ...        ...
# 21598  8956200760  20141013T000000  541800.0         4       2.50
# 21602   844000965  20140626T000000  224000.0         3       1.75
# 21604  9834201367  20150126T000000  429000.0         3       2.00
# 21605  3448900210  20141014T000000  610685.0         4       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 42            3595      5639     2.0           0     0  ...      9
# ...

# %%
houses[~recent_homes]
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21607  2997800021  20150219T000000  475000.0         3       2.50
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
titanic[titanic.survived == 0]
# Out:
#       pclass  survived                                             name  \
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# 7          1         0                           Andrews, Mr. Thomas Jr
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex   age  sibsp  parch    ticket     fare    cabin embarked boat  \
# ...

# %%
titanic[~(titanic.survived == 0)]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# ...      ...       ...                                              ...
# 1261       3         1                           Turkula, Mrs. (Hedwig)
# 1277       3         1                             Vartanian, Mr. David
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1300       3         1          Yasbeck, Mrs. Antoni (Selini Alexander)
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked   boat  \
# ...

# %% [markdown]
# ***
# ## $isna()$ $ve$ $notna()$ $Metotları$ $ile$ $Filtreleme$ $İşlemi$
# ***

# %% [markdown]
# **Metodun prototipi: `pandas.isna(obj)`**
#
# **isna() metodu, dizi tipli nesneler için *kayıp değer* tespiti yapar. Parametre olarak ise skaler ya da dizi tipli bir nesne alır ve bu nesnenin içerisinde kayıp değerler olup olmadığına bakar. Bu kayıp değerler, sayısal diziler için *NaN*, object tipli diziler için None ya da NaN ve zaman tipli diziler için ise NaT şeklinde karşımıza çıkar. Geriye, skaler girdiler için skaler yani tek bir bool değer döner, dizi tipli girdiler için ise her bir kayıp değere tekabül eden bir bool dizisi döner.**
#
# ***
# ***
#
# **Metodun prototipi: `pandas.notna(obj)`**
#
# **notna() metodu, dizi tipli nesneler için *kayıp olmayan değer* tespiti yapar. Parametre olarak ise skaler ya da dizi tipli bir nesne alır ve bu nesnenin içerisinde kayıp olmayan değerler olup olmadığına bakar. Kayıp değerler, sayısal diziler için *NaN*, object tipli diziler için None ya da NaN ve zaman tipli diziler için ise NaT şeklinde karşımıza çıkar. Geriye, skaler girdiler için skaler yani tek bir bool değer döner, dizi tipli girdiler için ise her bir kayıp olmayan değere tekabül eden bir bool dizisi döner.**

# %%
# Netflix veri setinin boyutlarını inceleyelim.
netflix.shape
# Out:
# (8807, 12)

# %%
# 8807 satır yani örnek olduğunu görüyoruz.
# Şimdi de hangi sütunlarda ne kadar null olmayan değer olduğunu inceleyelim.
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
# Yukarıda yaptığımız işlem ile "director" sütununda null değerler olduğunu görebiliyoruz.
# Bu null değerleri inceleyelim.
netflix[netflix["director"].isna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %%
# Kaç adet null değerler olduğunu inceleyelim.
netflix[netflix["director"].isna()].shape
# Out:
# (2634, 12)

# %%
# Hem "director" sütunu için hem de "cast" sütunu için null değerlere sahip olan örnekleri inceleyelim.
netflix[netflix["director"].isna() & netflix["cast"].isna()]
# Out:
#      show_id     type                                title director cast  \
# 3         s4  TV Show                Jailbirds New Orleans      NaN  NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN  NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN  NaN
# 66       s67  TV Show        Raja Rasoi Aur Anya Kahaniyan      NaN  NaN
# 69       s70  TV Show       Stories by Rabindranath Tagore      NaN  NaN
# ...      ...      ...                                  ...      ...  ...
# 8605   s8606  TV Show                            Top Grier      NaN  NaN
# 8609   s8610  TV Show                               Towies      NaN  NaN
# 8700   s8701  TV Show                    Wartime Portraits      NaN  NaN
# 8755   s8756  TV Show                    Women Behind Bars      NaN  NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN  NaN
#
#             country          date_added  release_year rating   duration  \
# ...

# %%
# Director sütunu null değer içermeyen örnekleri inceleyelim.
netflix[netflix["director"].notna()]
# Out:
#      show_id     type                             title  \
# 0         s1    Movie              Dick Johnson Is Dead
# 2         s3  TV Show                         Ganglands
# 5         s6  TV Show                     Midnight Mass
# 6         s7    Movie  My Little Pony: A New Generation
# 7         s8    Movie                           Sankofa
# ...      ...      ...                               ...
# 8801   s8802    Movie                           Zinzana
# 8802   s8803    Movie                            Zodiac
# 8804   s8805    Movie                        Zombieland
# 8805   s8806    Movie                              Zoom
# 8806   s8807    Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 2                   Julien Leclercq
# 5                     Mike Flanagan
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# ...                             ...
# ...

# %%
# Aşağıdaki bitwise negation operatörünü ve notna() metodunu birlikte kullanarak aslında isna() metodu çalışıtırmış oluyoruz.
netflix[~netflix["director"].notna()]
# Out:
#      show_id     type                                title director  \
# 1         s2  TV Show                        Blood & Water      NaN
# 3         s4  TV Show                Jailbirds New Orleans      NaN
# 4         s5  TV Show                         Kota Factory      NaN
# 10       s11  TV Show  Vendetta: Truth, Lies and The Mafia      NaN
# 14       s15  TV Show      Crime Stories: India Detectives      NaN
# ...      ...      ...                                  ...      ...
# 8795   s8796  TV Show                      Yu-Gi-Oh! Arc-V      NaN
# 8796   s8797  TV Show                           Yunus Emre      NaN
# 8797   s8798  TV Show                            Zak Storm      NaN
# 8800   s8801  TV Show                   Zindagi Gulzar Hai      NaN
# 8803   s8804  TV Show                          Zombie Dumb      NaN
#
#                                                    cast  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# ...

# %% [markdown]
# ***
# ## $Filtreleme$ $ve$ $Görselleştirme$ $Egzersizleri$
# ***

# %%
# Titanik kazasından kurtulan ya da kurtulamayan kadın yolcuların sayısını inceleyelim.
titanic[titanic["sex"] == "female"]["survived"].value_counts()
# Out:
# 1    339
# 0    127
# Name: survived, dtype: int64

# %%
# Titanik kazasından kurtulan ya da kurtulamayan erkek yolcuların sayısını inceleyelim.
titanic[titanic["sex"] == "male"]["survived"].value_counts()
# Out:
# 0    682
# 1    161
# Name: survived, dtype: int64

# %%
women = titanic["sex"] == "female"

# %%
titanic[women]["survived"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
titanic[~women]["survived"].value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='survived'>

# %%
houses[houses["price"] > 3000000]["zipcode"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
houses["zipcode"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>
