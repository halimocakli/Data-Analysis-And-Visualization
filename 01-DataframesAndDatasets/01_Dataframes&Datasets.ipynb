# %%
# Gerekli kütüphaneyi import edelim
import pandas as pd

# %%
# read_csv() -> CSV formatındaki veri setini dataframe formatında import sağlayan pandas metodu.
states = pd.read_csv("../Sources/data/states.csv")

# %%
# "states" dataframe'ini inceleyelim.
states
# Out:
#                    State  Abbrev Code
# 0                Alabama    Ala.   AL
# 1                 Alaska  Alaska   AK
# 2                Arizona   Ariz.   AZ
# 3               Arkansas    Ark.   AR
# 4             California  Calif.   CA
# 5               Colorado   Colo.   CO
# 6            Connecticut   Conn.   CT
# 7               Delaware    Del.   DE
# 8   District of Columbia    D.C.   DC
# 9                Florida    Fla.   FL
# 10               Georgia     Ga.   GA
# 11                Hawaii  Hawaii   HI
# 12                 Idaho   Idaho   ID
# 13              Illinois    Ill.   IL
# 14               Indiana    Ind.   IN
# 15                  Iowa    Iowa   IA
# 16                Kansas   Kans.   KS
# 17              Kentucky     Ky.   KY
# 18             Louisiana     La.   LA
# 19                 Maine   Maine   ME
# 20              Maryland     Md.   MD
# 21         Massachusetts   Mass.   MA
# 22              Michigan   Mich.   MI
# 23             Minnesota   Minn.   MN
# ...

# %% [markdown]
# ***
# ## King County Ev Satış Veri Seti
# This dataset includes the home sales from 2014-2015 in King County, WA (the county Seattle is located in)
# * `id` - house's unique id
# * `date` - sale date
# * `price` - sale price
# * `bedrooms` - number of bedrooms
# * `bathrooms` - numbers of bathrooms
# * `sqft_living` - living space square footage
# * `sqft_lot` - total lot square footage
# * `floors` - numbers of floors
# * `waterfront` - is the house waterfront (1) or not (0)
# * `view` - rating from 0 to 4 of how good the view from the house is
# * `condition` - rating from 1 (poor) to 5 (very good) of the condition of the house
# * `grade` - rating from 1-13 representing the construction quality of improvements. 1-3 Falls short of minimum building standards (cabins, etc.) 7 is avg grade, 11-13 have high-quality design & construction
# * `sqft_above` - square footage of the interior that is above ground level
# * `sqft_basement` - square footage of the interior that is below ground level
# * `yr_built` - year the house was initially built
# * `yr_renovated` - The year of the house’s last renovation (if any)
# * `zipcode` - zipcode that the house is located in
# * `lat` - the property's latitude
# * `long` - the property's longitude
# * `sqft_living15` - average interior space square footage of the nearest 15 neighbors
# * `sqft_lot15` - average lot square footage of the nearest 15 neighbors

# %%
# Ev bilgilerinin bulunduğu veri setini import edelim.
houses = pd.read_csv("../Sources/data/kc_house_data.csv")

# %%
# "houses" dataframe'ini inceleyelim.
houses
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# ...

# %%
# "houses" dataframe'inin veri tipini inceleyelim.
type(houses)
# Out:
# pandas.core.frame.DataFrame

# %%
# houses dataframe'inin sütunlarını inceleyelim.
# Bu işlemi Pandas kütüphanesinin "columns" attribute'unu kullanarak gerçekleştiriyoruz.
houses.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
# Sütunları daha düzenli olacak şekilde görebilmek adına aşağıdaki kod parçasını kullanabiliriz.
for column in houses.columns:
    print(f"{houses.columns.get_loc(column)}. Column of houses dataframe: {column}")
# Out:
# 0. Column of houses dataframe: id
# 1. Column of houses dataframe: date
# 2. Column of houses dataframe: price
# 3. Column of houses dataframe: bedrooms
# 4. Column of houses dataframe: bathrooms
# 5. Column of houses dataframe: sqft_living
# 6. Column of houses dataframe: sqft_lot
# 7. Column of houses dataframe: floors
# 8. Column of houses dataframe: waterfront
# 9. Column of houses dataframe: view
# 10. Column of houses dataframe: condition
# 11. Column of houses dataframe: grade
# 12. Column of houses dataframe: sqft_above
# 13. Column of houses dataframe: sqft_basement
# 14. Column of houses dataframe: yr_built
# 15. Column of houses dataframe: yr_renovated
# 16. Column of houses dataframe: zipcode
# 17. Column of houses dataframe: lat
# 18. Column of houses dataframe: long
# 19. Column of houses dataframe: sqft_living15
# 20. Column of houses dataframe: sqft_lot15

# %%
# states dataframe'inin sütunlarını inceleyelim
states.columns
# Out:
# Index(['State', 'Abbrev', 'Code'], dtype='object')

# %%
# Sütunları daha düzenli olacak şekilde görebilmek adına aşağıdaki kod parçasını kullanabiliriz.
for column in states.columns:
    print(f"{states.columns.get_loc(column)}. Column of states dataframe: {column}")
# Out:
# 0. Column of states dataframe: State
# 1. Column of states dataframe: Abbrev
# 2. Column of states dataframe: Code

# %%
# len() metodu -> dataframe içerisindeki satır sayısını verir.
len(houses)
# Out:
# 21613

# %%
# shape -> satır ve sütun sayısını verir, geriye bir Tuple veri tipi döndürür.
# houses dataframe'inin satır ve sütun sayısını öğrenelim
houses.shape
# Out:
# (21613, 21)

# %%
# size -> Satır Sayısı x Sütun Sayısı
# houses dataframe'inin boyutunu öğrenelim
houses.size
# Out:
# 453873

# %%
# İlk 100 satırı görebilmek için min_rows attribute'u üzerinde manipülasyon yapıyoruz.
pd.options.display.min_rows = 100

# %%
# Gerçekleştirdiğimiz manipülasyonun ardından houses dataframe'ini yeniden inceleyelim.
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# 7      2008000270  20150115T000000   291850.0         3       1.50
# 8      2414600126  20150415T000000   229500.0         3       1.00
# 9      3793500160  20150312T000000   323000.0         3       2.50
# 10     1736800520  20150403T000000   662500.0         3       2.50
# 11     9212900260  20140527T000000   468000.0         2       1.00
# 12      114101516  20140528T000000   310000.0         3       1.00
# ...

# %%
# Görmek istediğimiz satır sayısını 15 yapalım
pd.options.display.min_rows = 15

# %%
houses
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000   221900.0         3       1.00
# 1      6414100192  20141209T000000   538000.0         3       2.25
# 2      5631500400  20150225T000000   180000.0         2       1.00
# 3      2487200875  20141209T000000   604000.0         4       3.00
# 4      1954400510  20150218T000000   510000.0         3       2.00
# 5      7237550310  20140512T000000  1225000.0         4       4.50
# 6      1321400060  20140627T000000   257500.0         3       2.25
# ...           ...              ...        ...       ...        ...
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# ...

# %%
# head() metodu, default olarak dataframe'in ilk beş satırını görmemizi sağlar.
first_5 = houses.head()

# %%
first_5
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
# ...

# %%
type(first_5)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# * Son 4 hücredeki işlemlere bakarak, head() metodunun geriye bir DataFrame döndürdüğünü anlayabiliriz.

# %%
first_10 = houses.head(10)

# %%
first_10
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
first_200 = houses.head(200)

# %%
first_200
# Out:
#              id             date      price  bedrooms  bathrooms  sqft_living  \
# 0    7129300520  20141013T000000   221900.0         3       1.00         1180
# 1    6414100192  20141209T000000   538000.0         3       2.25         2570
# 2    5631500400  20150225T000000   180000.0         2       1.00          770
# 3    2487200875  20141209T000000   604000.0         4       3.00         1960
# 4    1954400510  20150218T000000   510000.0         3       2.00         1680
# 5    7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6    1321400060  20140627T000000   257500.0         3       2.25         1715
# ..          ...              ...        ...       ...        ...          ...
# 193  3663500060  20140625T000000   400000.0         3       2.50         2180
# 194  3996900125  20141201T000000   230000.0         3       1.00         1060
# 195  7796450200  20140515T000000   256883.0         3       2.50         1690
# ...

# %%
# head() metodu, default olarak dataframe'in ilk beş satırını görmemizi sağlar.
last_5 = houses.tail()

# %%
last_5
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 21608        1530              0      2009             0    98103  47.6993
# ...

# %%
last_9 = houses.tail(9)

# %%
last_9
# Out:
#                id             date      price  bedrooms  bathrooms  \
# 21604  9834201367  20150126T000000   429000.0         3       2.00
# 21605  3448900210  20141014T000000   610685.0         4       2.50
# 21606  7936000429  20150326T000000  1007500.0         4       3.50
# 21607  2997800021  20150219T000000   475000.0         3       2.50
# 21608   263000018  20140521T000000   360000.0         3       2.50
# 21609  6600060120  20150223T000000   400000.0         4       2.50
# 21610  1523300141  20140623T000000   402101.0         2       0.75
# 21611   291310100  20150116T000000   400000.0         3       2.50
# 21612  1523300157  20141015T000000   325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 21604         1490      1126     3.0           0     0  ...      8
# 21605         2520      6023     2.0           0     0  ...      9
# 21606         3510      7200     2.0           0     0  ...      9
# ...

# %% [markdown]
# ***
# **Hem head() metodu hem de tail() metodu yeni bir DataFrame döndürür ve her ikisinin de default parametresi 5'tir.**
# ***

# %%
# info() metodu, üzerinde çalıştığımız dataframe hakkında bazı bilgileri elde edebilmemizi sağlar.
# houses dataframe'i içerisindeki sütunların barındığı verilerin türünü ve sayısını inceleyelim.
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
# ...

# %%
states.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   State   51 non-null     object
#  1   Abbrev  51 non-null     object
#  2   Code    51 non-null     object
# dtypes: object(3)
# memory usage: 1.3+ KB

# %% [markdown]
# * Pandas, `string` tipindeki değişkenleri iki şekilde tutar:
#     1. `object` veri tipi olarak ki bu tip stringler başta olmak üzere bütün Python objelerini kapsar.
#     1. `StringDtype` tipinde tutar ki bu tip adından da anlaşılacağı üzere string tipindeki değişkenlere özeldir.

# %%
# dtypes, Sütunların tuttuğu verilerin veri tipini öğrenmemizi sağlar.
# houses dataframe'i içeriindeki sütunların barındığı verilerin türünü inceleyelim.
houses.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %% [markdown]
# ***
# ## Titanic Veri Seti Analizi

# %%
# Titanic veri setini import edelim.
titanic = pd.read_csv("../Sources/data/titanic.csv")

# %%
# titanic dataframe'inin ilk beş örneğini inceleyelim.
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ### Feature'lar
#
# * `pclass` - Passenger Class (1 = 1st; 2 = 2nd; 3 = 3rd)
# * `survived` - Survival (0 = No; 1 = Yes)
# * `name` - Name
# * `sex` - Sex
# * `age` - Age
# * `sibsp` - Number of Siblings/Spouses Aboard
# * `parch` - Number of Parents/Children Aboard
# * `ticket` - Ticket Number
# * `fare` - Passenger Fare
# * `cabin` - Cabin
# * `embarked` - Port of Embarkation (C = Cherbourg; Q = Queenstown; S = Southampton)
# * `boat` - Lifeboat (if survived)
# * `body` - Body number (if did not survive and body was recovered)
# * `home.dest` - Home/Destination

# %%
# titanic dataframe'inin sütunlarını görelim.
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
# titanic dataframe'inin son on örneğini inceleyelim.
titanic.tail(10)
# Out:
#       pclass  survived                                     name     sex   age  \
# 1299       3         0                      Yasbeck, Mr. Antoni    male    27
# 1300       3         1  Yasbeck, Mrs. Antoni (Selini Alexander)  female    15
# 1301       3         0                     Youseff, Mr. Gerious    male  45.5
# 1302       3         0                        Yousif, Mr. Wazli    male     ?
# 1303       3         0                    Yousseff, Mr. Gerious    male     ?
# 1304       3         0                     Zabour, Miss. Hileni  female  14.5
# 1305       3         0                    Zabour, Miss. Thamine  female     ?
# 1306       3         0                Zakarian, Mr. Mapriededer    male  26.5
# 1307       3         0                      Zakarian, Mr. Ortin    male    27
# 1308       3         0                       Zimmerman, Mr. Leo    male    29
#
#       sibsp  parch  ticket     fare cabin embarked boat body home.dest
# ...

# %%
# titanic dataframe'inin sütunlarının barındırdığı verilerin türünü ve sayısını görelim.
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %% [markdown]
# ***
# ***age* feature'u, içerisinde birbirinden farklı tipte nümerik veriler barındırdığı için `object` tipinde karşımıza çıkıyor**
# ***

# %%
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# ...

# %% [markdown]
# ## *read_csv()* Metodunun ',' İşaretinin Ayırıcı Olarak Kullanılmadığı Veri Setlerine Uygulanması
#
# * `netflix_titles.csv` dosyası içerisindeki veriler, pipe (`|`) karakteri ile birbirinden ayrılmış durumda. `read_csv()` metodunu kullanırken `sep="|"` şeklinde bir parametre kullanarak bu dosyadaki verileri düzgünce  import edebiliriz.
#
#
# * Bununla birlikte, Netflix veri setinin ilk sütununda bir index sütunu bulunur. Bu sütunun dataframe'e aktarabilmek adına `index_col=0` parametresi kullanılır.

# %%
# `netflix_titles.csv` veri setini import edelim.
netflix = pd.read_csv("../Sources/data/netflix_titles.csv", sep="|", index_col=0)

# %%
# netflix dataframe'i içerisindeki örnek sayısını, sütunları ve sütunların barındırdığı verilerin türünü inceleyelim.
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 894.5+ KB

# %%
# netflix dataset'inin ilk 5 örneğini inceleyelim.
netflix.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# ***
# ## Yeni Sütun İsimleri Eklemek
#
#
# `read_csv` metodunu, `names` parametresi ile birlikte kullanarak kendi hazırladığımız sütun isimlerini dataframe'e aktarabiliriz. Bununla birlikte **`header=0`** ifadesini de `read_csv` metoduna ekleyerek, orijinal sütun isimlerinin orijinal dosyadanın ilk satırında olduğunu ve karışıklık yaşanmaması adına bu satırın görmezden gelinmesi gerektiğini belirtebiliriz.

# %%
# Üzerinde çalışacağımız veri setini inceleyelim
pd.read_csv("../Sources/data/nst-est2020.csv")
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
# Sütun isimlerini değiştirmek için yeni isimleri bir liste içerisinde tutalım
names = ['sumlev', 'region', 'division', 'state', 'name', 'census2010pop', 'estimatesbase2010', 'popestimate2010', 'popestimate2011', 'popestimate2012', 'popestimate2013', 'popestimate2014', 'popestimate2015', 'popestimate2016', 'popestimate2017', 'popestimate2018', 'popestimate2019', 'popestimate042020', 'popestimate2020']

# %%
# Şimdi de yeni isimleri kullanarak veri setini inceleyelim
pd.read_csv("../Sources/data/nst-est2020.csv", names=names)
# Out:
#     sumlev  region  division  state                  name  census2010pop  \
# 0   SUMLEV  REGION  DIVISION  STATE                  NAME  CENSUS2010POP
# 1      010       0         0     00         United States      308745538
# 2      020       1         0     00      Northeast Region       55317240
# 3      020       2         0     00        Midwest Region       66927001
# 4      020       3         0     00          South Region      114555744
# 5      020       4         0     00           West Region       71945553
# 6      040       3         6     01               Alabama        4779736
# 7      040       4         9     02                Alaska         710231
# 8      040       4         8     04               Arizona        6392017
# 9      040       3         7     05              Arkansas        2915918
# 10     040       4         9     06            California       37253956
# 11     040       4         8     08              Colorado        5029196
# ...

# %% [markdown]
# ***
# **Dikkat ederseniz, dataframe'in sütunlarının ismimlerini belirlediğimiz isimlerle değiştirdiğimizde, orijinal veri setinin ilk örneğindeki sütun isimleri bir veri gibi davranarak dataframe'e dahil oluyor. Karışıklık olmaması adına bu durumun önüne geçmek istiyoruz. Bu nedenle yukarıda bahsedildiği gibi `header` parametresine `0` atayarak orijinal sütun isimlerinin korunmasını ancak görmezden gelinerek yeni sütun isimlerinin gösterilmesini sağlayacağız.**
# ***

# %%
# Veri setimizi yeni isimlerle ve düzenlenmiş halde import edelim
state_pops = pd.read_csv("../Sources/data/nst-est2020.csv", names=names, header=0)

# %%
# dataframe'in ilk beş örneğini görelim.
state_pops.head()
# Out:
#    sumlev region division  state              name  census2010pop  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
#
#    estimatesbase2010  popestimate2010  popestimate2011  popestimate2012  \
# 0          308758105        309327143        311583481        313877662
# 1           55318414         55380764         55608318         55782661
# 2           66929737         66975328         67164092         67348275
# 3          114563042        114869421        116019483        117264196
# 4           71946912         72101630         72791588         73482530
#
#    popestimate2013  popestimate2014  popestimate2015  popestimate2016  \
# ...

# %%
# Yukarıda da görüldüğü üzere amacımıza ulaştık.
# Daha iyi anlamak için orijinal data frame'deki sütun isimlerinin değişip değişmediğine bakalım.
pd.read_csv("../Sources/data/nst-est2020.csv").head()
# Out:
#    SUMLEV REGION DIVISION  STATE              NAME  CENSUS2010POP  \
# 0      10      0        0      0     United States      308745538
# 1      20      1        0      0  Northeast Region       55317240
# 2      20      2        0      0    Midwest Region       66927001
# 3      20      3        0      0      South Region      114555744
# 4      20      4        0      0       West Region       71945553
#
#    ESTIMATESBASE2010  POPESTIMATE2010  POPESTIMATE2011  POPESTIMATE2012  \
# 0          308758105        309327143        311583481        313877662
# 1           55318414         55380764         55608318         55782661
# 2           66929737         66975328         67164092         67348275
# 3          114563042        114869421        116019483        117264196
# 4           71946912         72101630         72791588         73482530
#
#    POPESTIMATE2013  POPESTIMATE2014  POPESTIMATE2015  POPESTIMATE2016  \
# ...

# %% [markdown]
# ***
# **Görüldüğü gibi orijinal dataframe'de herhangi bir değişiklik olmadı. Buradan anlıyoruz ki sütün isimlerini `names` parametresi ile değiştirken aslında sütun isimlerini belirlenen isimlerle göstermiş oluyoruz ya da yeni sütun isimlerine sahip bir dataframe oluştururuz. Bu işlem, veri üzerinde çalışırken kafa karışıklılığı yaratmamak adına kullanılıp işleri hızlandırabilir.**
# ***
